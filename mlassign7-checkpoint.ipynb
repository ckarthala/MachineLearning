# %%
import pandas as pd
data=pd.read_csv('mlassignment7.csv')

# %%
data.drop(['DOB'],axis=1,inplace=True)

# %%
import seaborn as sns

# %%
sns.pairplot(data)

# %%
X = data[['Age At Surgery']].values
y= data[['Gender']].values
import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X, y)
print(reg.score(X, y))
print(reg.coef_)
print(reg.intercept_)
#reg.predict(np.array([[3, 5]]))
# Out:
# 0.238117769916376
# [[-0.02173174]]
# [2.8805746]

# %%
data.corr()
# Out:
#                       ID  Age At Surgery    Gender      Race
# ID              1.000000       -0.134303  0.057585  0.015767
# Age At Surgery -0.134303        1.000000 -0.487973  0.027045
# Gender          0.057585       -0.487973  1.000000  0.004498
# Race            0.015767        0.027045  0.004498  1.000000
